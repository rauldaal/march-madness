# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
MRegularSeasonDetailedResults = pd.read_csv("data/MRegularSeasonDetailedResults.csv")
selected_season = 2023
selected_team = 1104

MRegularSeasonDetailedResults[(MRegularSeasonDetailedResults['Season'] == selected_season) & ((MRegularSeasonDetailedResults['WTeamID'] == selected_team) | (MRegularSeasonDetailedResults['LTeamID'] == selected_team))]
# Out:
#         Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  \
# 102034    2023       7     1104      75     1255      54    H      0    27
# 102211    2023      11     1104      95     1251      59    H      0    27
# 102398    2023      15     1104      65     1375      55    A      0    22
# 102526    2023      18     1104     104     1240      62    H      0    34
# 102879    2023      24     1104      81     1277      70    N      0    28
# 102904    2023      25     1163      82     1104      67    N      0    26
# 103046    2023      27     1104     103     1314     101    N      4    37
# 103274    2023      33     1104      78     1355      65    H      0    27
# 103528    2023      40     1104      71     1222      65    A      0    22
# 103676    2023      43     1104      91     1272      88    H      0    26
# 103783    2023      47     1211     100     1104      90    N      0    40
# ...

# %%
# Out:
# Season     2003    2004    2005    2006    2007    2008    2009    2010  \
# WTeamID
# 1101        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1102      825.0  1404.0  1097.0  1430.0  1591.0   886.0   553.0   551.0
# 1103     1141.0   973.0  1358.0  1544.0  1907.0  1707.0  1534.0  1714.0
# 1104     1270.0  1298.0  1823.0  1269.0  1536.0  1383.0  1216.0  1236.0
# 1105      556.0   984.0  1158.0   911.0   443.0   786.0   504.0   580.0
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 1474        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1475        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1476        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1477        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1478        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# Season     2011    2012  ...    2015    2016    2017    2018    2019    2020  \
# ...
